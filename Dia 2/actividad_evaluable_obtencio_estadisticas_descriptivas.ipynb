# %% [markdown]
# Carga los datos usando tu lector de csv o con pandas. Es recomendable hacerlo con pandas.

# %%
import pandas as pd
data = pd.read_csv("covid19_tweets.csv")
data.head()
# Out:
#          user_name         user_location  \
# 0           ᏉᎥ☻լꂅϮ            astroworld
# 1    Tom Basile 🇺🇸          New York, NY
# 2  Time4fisticuffs      Pewee Valley, KY
# 3      ethel mertz  Stuck in the Middle
# 4         DIPR-J&K     Jammu and Kashmir
#
#                                     user_description         user_created  \
# 0  wednesday addams as a disney princess keepin i...  2017-05-26 05:46:42
# 1  Husband, Father, Columnist & Commentator. Auth...  2009-04-16 20:06:23
# 2  #Christian #Catholic #Conservative #Reagan #Re...  2009-02-28 18:57:41
# 3  #Browns #Indians #ClevelandProud #[]_[] #Cavs ...  2019-03-07 01:45:06
# 4  🖊️Official Twitter handle of Department of Inf...  2017-02-12 06:45:15
#
#    user_followers  user_friends  user_favourites  user_verified  \
# 0             624           950            18775          False
# 1            2253          1677               24           True
# 2            9275          9525             7254          False
# ...

# %% [markdown]
# Verifica la cantidad de datos que tienes, las variables que contiene cada vector de datos e identifica el tipo de variables.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74436 entries, 0 to 74435
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   user_name         74436 non-null  object
#  1   user_location     59218 non-null  object
#  2   user_description  70079 non-null  object
#  3   user_created      74436 non-null  object
#  4   user_followers    74436 non-null  int64
#  5   user_friends      74436 non-null  int64
#  6   user_favourites   74436 non-null  int64
#  7   user_verified     74436 non-null  bool
#  8   date              74436 non-null  object
#  9   text              74436 non-null  object
#  10  hashtags          53002 non-null  object
#  11  source            74424 non-null  object
#  12  is_retweet        74436 non-null  bool
# dtypes: bool(2), int64(3), object(8)
# memory usage: 6.4+ MB

# %%
data.count()
# Out:
# user_name           74436
# user_location       59218
# user_description    70079
# user_created        74436
# user_followers      74436
# user_friends        74436
# user_favourites     74436
# user_verified       74436
# date                74436
# text                74436
# hashtags            53002
# source              74424
# is_retweet          74436
# dtype: int64

# %% [markdown]
# Analiza las variables para saber qué representa cada una y en qué rangos se encuentran. Si la descripción del problema no te lo indica, utiliza el máximo y el mínimo para encontrarlo.

# %%
data.describe()
# Out:
#        user_followers   user_friends  user_favourites
# count    7.443600e+04   74436.000000     7.443600e+04
# mean     1.059513e+05    2154.721170     1.529747e+04
# std      8.222900e+05    9365.587474     4.668971e+04
# min      0.000000e+00       0.000000     0.000000e+00
# 25%      1.660000e+02     153.000000     2.200000e+02
# 50%      9.600000e+02     552.000000     1.927000e+03
# 75%      5.148000e+03    1780.250000     1.014800e+04
# max      1.389284e+07  497363.000000     2.047197e+06

# %%
data.describe(include = object).transpose()
# Out:
#                   count unique  \
# user_name         74436  44853
# user_location     59218  14622
# user_description  70079  42690
# user_created      74436  45554
# date              74436  56546
# text              74436  74312
# hashtags          53002  23445
# source            74424    450
#
#                                                                 top   freq
# user_name                                        GlobalPandemic.NET    312
# user_location                                                 India   1496
# user_description  Breaking News & Critical Information to SURVIV...    312
# user_created                                    2010-07-13 21:58:05    312
# date                                            2020-07-29 16:30:00     26
# text              Greenland has no active cases of the novel cor...      6
# hashtags                                                ['COVID19']  16004
# source                                              Twitter Web App  22974

# %%
len(data)
# Out:
# 74436

# %%
data.sort_values(['user_followers'], ascending = False).groupby('user_name').head(10)
# Out:
#                   user_name   user_location  \
# 6959                   CGTN  Beijing, China
# 13450                  CGTN  Beijing, China
# 16194                  CGTN  Beijing, China
# 235                    CGTN  Beijing, China
# 2837                   CGTN  Beijing, China
# ...                     ...             ...
# 31343                roland             NaN
# 54006            kimberly s             NaN
# 23222           Barry Kerry         Bristol
# 59125                    小D             NaN
# 6084   Medilight Healthcare             NaN
#
#                                         user_description         user_created  \
# 6959   #SeeTheDifference with CGTN as we bring you st...  2013-01-24 03:18:59
# 13450  #SeeTheDifference with CGTN as we bring you st...  2013-01-24 03:18:59
# 16194  #SeeTheDifference with CGTN as we bring you st...  2013-01-24 03:18:59
# 235    #SeeTheDifference with CGTN as we bring you st...  2013-01-24 03:18:59
# ...

# %%
data.sort_values(['user_followers'], ascending = True).groupby('user_name').head(10)
# Out:
#               user_name   user_location  \
# 46763            Harman             NaN
# 37676             Rashi             NaN
# 53241  david derbyshire             NaN
# 50635    Sinoi Mataalii             NaN
# 29853               MAB             NaN
# ...                 ...             ...
# 38250              CGTN  Beijing, China
# 36181              CGTN  Beijing, China
# 17823              CGTN  Beijing, China
# 20378              CGTN  Beijing, China
# 20483              CGTN  Beijing, China
#
#                                         user_description         user_created  \
# 46763                                                NaN  2019-06-12 07:02:45
# 37676                                                NaN  2020-07-28 03:55:31
# 53241                                                NaN  2019-08-15 10:38:23
# 50635                                                NaN  2020-06-05 20:18:27
# 29853                                                NaN  2020-03-28 23:17:44
# ...

# %%
data.sort_values(['user_location'], ascending = True).groupby('user_name').head(10)
# Out:
#               user_name   user_location  \
# 46098              Blqi  \nˢᵒᵐᵉʷʰᵉʳᵉ\n🖤
# 46109              Blqi  \nˢᵒᵐᵉʷʰᵉʳᵉ\n🖤
# 44436             Janci
# 62091  Wild Goose #TNCM
# 7306   Wild Goose #TNCM
# ...                 ...             ...
# 74412   USAID Indonesia             NaN
# 74415           CPI (M)             NaN
# 74427    Ifeanyi Okafor             NaN
# 74428     Peter Critter             NaN
# 74434             M0ser             NaN
#
#                                         user_description         user_created  \
# 46098       At the end of the day, is night 🌝.    偽の愛 🇹🇹  2018-08-20 20:02:57
# 46109       At the end of the day, is night 🌝.    偽の愛 🇹🇹  2018-08-20 20:02:57
# 44436                                                NaN  2011-07-28 15:55:21
# 62091  Veteran market strategist. Cantillon not Law! ...  2014-12-03 18:15:49
# 7306   Veteran market strategist. Cantillon not Law! ...  2014-12-03 18:15:49
# ...

# %%
data.sort_values(['user_location'], ascending = False).groupby('user_name').head(10)
# Out:
#                             user_name user_location  \
# 2572                   ✊Franc-Tireur🗽             🪐
# 11869                      🐝BeeHappy🐝             🪐
# 11692                      🐝BeeHappy🐝             🪐
# 11618                      🐝BeeHappy🐝             🪐
# 27153  🏳️‍🌈ÐΛⱤƬⱧ §ⱠӨ₮Я🇪🇸🇮🇪🏴󠁧󠁢󠁳󠁣󠁴󠁿🇬🇧🇺🇸   🦄🌈❤️🧡💛💚💙💜🌈🦄
# ...                               ...           ...
# 74412                 USAID Indonesia           NaN
# 74415                         CPI (M)           NaN
# 74427                  Ifeanyi Okafor           NaN
# 74428                   Peter Critter           NaN
# 74434                           M0ser           NaN
#
#                                         user_description         user_created  \
# 2572   Committed to getting into #GoodTrouble #ICantB...  2014-10-28 15:00:14
# 11869                                                🏝🏖🏔  2020-01-24 19:49:32
# 11692                                                🏝🏖🏔  2020-01-24 19:49:32
# ...

# %%
counts = data['user_verified'].value_counts().to_dict()
print(counts)
# Out:
# {False: 65082, True: 9354}

# %%
counts = data['source'].value_counts().to_dict()
print(counts)
# Out:
# {'Twitter Web App': 22974, 'Twitter for Android': 16758, 'Twitter for iPhone': 15824, 'TweetDeck': 3453, 'Hootsuite Inc.': 2846, 'Twitter for iPad': 1884, 'Buffer': 1081, 'Instagram': 854, 'Sprout Social': 773, 'IFTTT': 542, 'GlobalPandemic.NET': 312, 'dlvr.it': 261, 'Twitter Media Studio': 247, 'FS Poster': 244, 'LinkedIn': 236, 'Sprinklr': 216, 'HubSpot': 187, 'COVID19-Updates': 181, 'Resistbot Open Letters': 177, 'WordPress.com': 170, 'Dynamic Signal': 168, 'Twitter for Advertisers': 134, 'Cheap Bots, Done Quick!': 132, 'Paper.li': 126, 'IAMBLOG2TWITTER': 120, 'Alexander Higgins': 112, 'Fabrik.fm': 98, 'Blood Donors India': 98, 'coronaData_Test': 92, 'Global Citizen Mobile App': 82, 'Oktopost': 80, 'Tweetbot for iΟS': 79, 'Zoho Social': 78, 'TweetCaster for Android': 78, 'LaterMedia': 74, 'SocialPilot.co': 74, 'SocialFlow': 72, 'Prof. Shanku': 72, 'The Social Jukebox': 71, 'Twitter for Mac': 69, 'Salesforce - Social Studio': 68, 'Khoros': 64, 'ContentStudio.io': 63, 'Social Media 
# ...

# %%
counts = data['is_retweet'].value_counts().to_dict()
print(counts)
# Out:
# {False: 74436}

# %%
counts = data['user_location'].value_counts().to_dict()
print(counts)
# Out:
# {'India': 1496, 'United States': 1172, 'New Delhi, India': 669, 'Washington, DC': 589, 'Mumbai, India': 554, 'New York, NY': 527, 'Los Angeles, CA': 420, 'USA': 405, 'Canada': 396, 'United Kingdom': 388, 'London, England': 380, 'California, USA': 378, 'Australia': 360, 'London': 353, 'WORLDWIDE': 346, 'Worldwide': 327, 'Switzerland': 310, 'New Delhi': 307, 'South Africa': 282, 'Lagos, Nigeria': 268, 'Atlanta, GA': 258, 'Global': 255, 'Chicago, IL': 250, 'Nairobi, Kenya': 247, 'UK': 239, 'Toronto, Ontario': 237, 'Nigeria': 235, 'Boston, MA': 227, 'San Francisco, CA': 222, 'Mumbai': 220, 'Johannesburg, South Africa': 205, 'Bhubaneshwar, India': 196, 'Hyderabad, India': 196, 'Florida, USA': 196, 'Houston, TX': 193, 'Texas, USA': 190, 'Earth': 189, 'Hong Kong': 186, 'Chennai, India': 185, 'Singapore': 179, 'Text RESIST to 50409': 177, 'New York, USA': 175, 'New York': 160, 'Las Vegas, NV': 159, 'Philippines': 158, 'Bengaluru, India': 154, 'Manila, Philippines': 148, 'San Diego, CA': 146,
# ...

# %%
data.iloc[1:, [5,6,7]]
# Out:
#        user_friends  user_favourites  user_verified
# 1              1677               24           True
# 2              9525             7254          False
# 3               987             1488          False
# 4               168              101          False
# 5              1071             1287          False
# ...             ...              ...            ...
# 74431           586             1902          False
# 74432          1066            53569          False
# 74433           102               16          False
# 74434          1733           129104          False
# 74435          1748            60133          False
#
# [74435 rows x 3 columns]

# %%
data.iloc[1:, [9,10]]
# Out:
#                                                     text  \
# 1      Hey @Yankees @YankeesPR and @MLB - wouldn't it...
# 2      @diane3443 @wdunlap @realDonaldTrump Trump nev...
# 3      @brookbanktv The one gift #COVID19 has give me...
# 4      25 July : Media Bulletin on Novel #CoronaVirus...
# 5      #coronavirus #covid19 deaths continue to rise....
# ...                                                  ...
# 74431  So far this summer I have filled up my lawn mo...
# 74432  ICYMI: REPLAY: #TechIntersect🧩 #16: Isaiah "@B...
# 74433  Community workers in Tianshan District of Urum...
# 74434  If only we had a responsible media to warn us ...
# 74435  MAGA: #COVID19 is just a cold &amp; it'd be go...
#
#                                       hashtags
# 1                                          NaN
# 2                                  ['COVID19']
# 3                                  ['COVID19']
# 4            ['CoronaVirusUpdates', 'COVID19']
# ...
